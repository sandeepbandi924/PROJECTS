# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in s:\projects_all\venv\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in s:\projects_all\venv\lib\site-packages (from openpyxl) (2.0.0)

# %%
data = pd.read_excel('Cleaned_Validation_Dataset.xlsx')

# %%
data.head()
# Out:
#         Date  Temp_0.3m_C  Temp_0.6m_C  Temp_0.91m_C  Temp_1.21m_C  \
# 0 2019-05-01     8.429167     8.237500      8.000000      7.600000
# 1 2019-05-02     8.950000     8.358333      8.012500      7.600000
# 2 2019-05-03    10.187500     8.950000      8.220833      7.654167
# 3 2019-05-04    11.241667     9.670833      8.620833      7.783333
# 4 2019-05-05    12.025000    10.337500      9.091667      7.979167
#
#    Rainfall_mm  Air_Temp_F  Air_Temp_C
# 0        1.778        48.8       9.333
# 1        4.826        53.7      12.056
# 2        3.810        55.6      13.111
# 3        8.128        53.3      11.833
# 4        0.000        52.3      11.278

# %%
data.shape
# Out:
# (1096, 8)

# %%
data.isna().sum()
# Out:
# Date             0
# Temp_0.3m_C     76
# Temp_0.6m_C      0
# Temp_0.91m_C     0
# Temp_1.21m_C     0
# Rainfall_mm      0
# Air_Temp_F       0
# Air_Temp_C       0
# dtype: int64

# %%
data['Rainfall (inch)'] = data['Rainfall_mm'] * 0.0393701
data['BH1_0.9m_Temp_C'] = data['Temp_0.91m_C']
data['BH1_0.6m_Temp_C'] = data['Temp_0.6m_C']
data['BH1_0.3m_Temp_C'] = data['Temp_0.3m_C']
data['BH1_1.21m_Temp_C'] = data['Temp_1.21m_C']

# %%
data.isna().sum()
# Out:
# Date                 0
# Temp_0.3m_C         76
# Temp_0.6m_C          0
# Temp_0.91m_C         0
# Temp_1.21m_C         0
# Rainfall_mm          0
# Air_Temp_F           0
# Air_Temp_C           0
# Rainfall (inch)      0
# BH1_0.9m_Temp_C      0
# BH1_0.6m_Temp_C      0
# BH1_0.3m_Temp_C     76
# BH1_1.21m_Temp_C     0
# dtype: int64

# %%
data.shape
# Out:
# (1020, 13)

# %%
data = data.dropna()

# %%
data['Date'] = pd.to_datetime(data['Date'])
data['day_of_year'] = data['Date'].dt.dayofyear

# %%
data.describe()
# Out:
#                                 Date  Temp_0.3m_C  Temp_0.6m_C  Temp_0.91m_C  \
# count                           1020  1020.000000  1020.000000   1020.000000
# mean   2020-11-29 19:03:31.764705792     9.989042    10.068921     10.094739
# min              2019-05-01 00:00:00     0.300000     1.000000      1.450000
# 25%              2020-03-26 18:00:00     2.021875     3.036458      3.561458
# 50%              2020-12-06 12:00:00     8.283333     8.400000      8.591667
# 75%              2021-08-18 06:00:00    17.965625    17.179167     16.201042
# max              2022-04-30 00:00:00    24.391667    22.933333     21.800000
# std                              NaN     7.933651     7.302904      6.746957
#
#        Temp_1.21m_C  Rainfall_mm   Air_Temp_F   Air_Temp_C  Rainfall (inch)  \
# count   1020.000000  1020.000000  1020.000000  1020.000000      1020.000000
# mean      10.141173     3.148853    47.258922     8.477162         0.123971
# min        2.116667     0.000000    -3.900000   -19.944000         0.000000
# 25%        4.500000     0.000000    33.275000     0.708250         0.000000
# 50%        8.922917     0.000000    46.400000     8.000000         0.000000
# 75%       15.678125     2.540000    63.725000    17.625000         0.100000
# max       20.100000    69.342000    83.100000    28.389000         2.730001
# std        5.875904     7.331768    18.513144    10.285079         0.288652
#
#        BH1_0.9m_Temp_C  BH1_0.6m_Temp_C  BH1_0.3m_Temp_C  BH1_1.21m_Temp_C  \
# count      1020.000000      1020.000000      1020.000000       1020.000000
# mean         10.094739        10.068921         9.989042         10.141173
# min           1.450000         1.000000         0.300000          2.116667
# 25%           3.561458         3.036458         2.021875          4.500000
# 50%           8.591667         8.400000         8.283333          8.922917
# 75%          16.201042        17.179167        17.965625         15.678125
# max          21.800000        22.933333        24.391667         20.100000
# std           6.746957         7.302904         7.933651          5.875904
#
#        day_of_year
# count  1020.000000
# mean    178.299020
# min       1.000000
# 25%      85.750000
# 50%     170.500000
# 75%     278.000000
# max     366.000000
# std     107.633131

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1020 entries, 0 to 1095
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              1020 non-null   datetime64[ns]
#  1   Temp_0.3m_C       1020 non-null   float64
#  2   Temp_0.6m_C       1020 non-null   float64
#  3   Temp_0.91m_C      1020 non-null   float64
#  4   Temp_1.21m_C      1020 non-null   float64
#  5   Rainfall_mm       1020 non-null   float64
#  6   Air_Temp_F        1020 non-null   float64
#  7   Air_Temp_C        1020 non-null   float64
#  8   Rainfall (inch)   1020 non-null   float64
#  9   BH1_0.9m_Temp_C   1020 non-null   float64
#  10  BH1_0.6m_Temp_C   1020 non-null   float64
#  11  BH1_0.3m_Temp_C   1020 non-null   float64
#  12  BH1_1.21m_Temp_C  1020 non-null   float64
#  13  day_of_year       1020 non-null   int32
# dtypes: datetime64[ns](1), float64(12), int32(1)
# memory usage: 115.5 KB

# %%
# Visualize the relationship between Air Temp and Temperatures at different depths
plt.figure(figsize=(10,6))
sns.scatterplot(x=data['Date'], y=data['BH1_0.9m_Temp_C'],palette='rocket')
plt.title('Date vs Temperature at 0.91m')
plt.show()

# %%
# Visualize the relationship between Air Temp and Temperatures at different depths
plt.figure(figsize=(10,6))
sns.scatterplot(x=data['Date'], y=data['BH1_0.6m_Temp_C'],color='r')
plt.title('Date vs Temperature at 0.6m')
plt.show()

# %%
# Visualize the relationship between Air Temp and Temperatures at different depths
sns.scatterplot(x=data['Air_Temp_C'], y=data['BH1_0.9m_Temp_C'],color='r')
plt.title('Air Temperature vs Temperature at 0.91m')
plt.show()

# %%
# Visualize the relationship between Air Temp and Temperatures at different depths
sns.scatterplot(x=data['Air_Temp_C'], y=data['BH1_0.6m_Temp_C'],color='r')
plt.title('Air Temperature vs Temperature at 0.6m')
plt.show()

# %%
# Visualize the relationship between Air Temp and Temperatures at different depths
sns.scatterplot(x=data['Rainfall (inch)'], y=data['BH1_0.9m_Temp_C'],color='r')
plt.title('Rainfall (inch) vs Temperature at 0.91m')
plt.show()

# %%
# Visualize the relationship between Air Temp and Temperatures at different depths
sns.scatterplot(x=data['Rainfall (inch)'], y=data['BH1_0.6m_Temp_C'],color='r')
plt.title('Rainfall (inch) vs Temperature at 0.6m')
plt.show()

# %%
# Visualize the relationship between Air Temp and Temperatures at different depths
sns.scatterplot(x=data['day_of_year'], y=data['BH1_0.9m_Temp_C'],color='r')
plt.title('Day Of Year vs Temperature at 0.91m')
plt.show()

# %%
# Visualize the relationship between Air Temp and Temperatures at different depths
sns.scatterplot(x=data['day_of_year'], y=data['BH1_0.6m_Temp_C'],color='r')
plt.title('Day Of Year vs Temperature at 0.6m')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
def remove_outliers(df, columns):
    Q1 = df[columns].quantile(0.25)
    Q3 = df[columns].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[~((df[columns] < lower_bound) | (df[columns] > upper_bound)).any(axis=1)]

# %%
cols=['Rainfall (inch)','BH1_0.9m_Temp_C','BH1_0.6m_Temp_C','Air_Temp_C','day_of_year','BH1_1.21m_Temp_C', 'BH1_0.3m_Temp_C']
data = remove_outliers(data, cols)

# %%
data.shape
# Out:
# (868, 14)

# %%
X = data[['Air_Temp_C', 'Rainfall (inch)', 'day_of_year']]
y = data[['BH1_0.9m_Temp_C', 'BH1_0.6m_Temp_C', 'BH1_0.3m_Temp_C', 'BH1_1.21m_Temp_C']]

# %%
X.head()
# Out:
#    Air_Temp_C  Rainfall (inch)  day_of_year
# 0       9.333             0.07          121
# 1      12.056             0.19          122
# 2      13.111             0.15          123
# 4      11.278             0.00          125
# 5      14.222             0.23          126

# %%
y.head()
# Out:
#    BH1_0.9m_Temp_C  BH1_0.6m_Temp_C  BH1_0.3m_Temp_C  BH1_1.21m_Temp_C
# 0         8.000000         8.237500         8.429167          7.600000
# 1         8.012500         8.358333         8.950000          7.600000
# 2         8.220833         8.950000        10.187500          7.654167
# 4         9.091667        10.337500        12.025000          7.979167
# 5         9.500000        10.775000        12.395833          8.204167

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
X.shape,X_train.shape,X_test.shape
# Out:
# ((868, 3), (651, 3), (217, 3))

# %%
#Starndardization (Scaling the data)

# from sklearn.preprocessing import StandardScaler
scaler_x = MinMaxScaler()
scaler_y=MinMaxScaler()

X_train = scaler_x.fit_transform(X_train)
X_test = scaler_x.transform(X_test)
# y_train = scaler_y.fit_transform(y_train)
# y_test = scaler_y.transform(y_test)

# %%
X_train
# Out:
# array([[0.22413258, 0.        , 0.0467033 ],
#        [0.64481824, 0.        , 0.8543956 ],
#        [0.380444  , 0.        , 0.02747253],
#        ...,
#        [0.55516935, 0.        , 0.30769231],
#        [0.51608632, 0.        , 0.95054945],
#        [0.53907268, 0.        , 0.90384615]])

# %%
# Machine Learning Libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score
import numpy as np

# %%
def evaluate_model(y_true, y_pred):
    """Calculate evaluation metrics."""
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    r2 = r2_score(y_true, y_pred)
    return mae, rmse, r2

# %%
# Define models
models = {
    "Linear Regression": LinearRegression(),
    "Lasso":Lasso(),
    "Ridge":Ridge(),
    "ElasticNet":ElasticNet(),
    "Decision Tree Regressor": DecisionTreeRegressor(),
    "Random Forest Regressor": RandomForestRegressor(),
    "GradientBoost":GradientBoostingRegressor(),
    'XGBRegressor':XGBRegressor(),
}

# %%
def train_and_evaluate(models, X_train, y_train, X_test, y_test):
    """Train and evaluate models, and identify the best model based on R² score."""
    results = {}
    best_model_name = None
    best_r2_score = -float('inf')  # Initialize to a very low value

    for model_name, model in models.items():
        print(f"Training {model_name}...")

        try:
            model.fit(X_train, y_train)  # Train the model

            # Make predictions
            y_train_pred = model.predict(X_train)
            y_test_pred = model.predict(X_test)

            # Evaluate Train and Test dataset
            model_train_metrics = evaluate_model(y_train, y_train_pred)
            model_test_metrics = evaluate_model(y_test, y_test_pred)

            # Store results
            results[model_name] = {
                "train_metrics": model_train_metrics,
                "test_metrics": model_test_metrics
            }

            # Print results
            print(f'{model_name} Performance:')
            print('- Training set:')
            print(f"  - RMSE: {model_train_metrics[1]:.4f}, MAE: {model_train_metrics[0]:.4f}, R2: {model_train_metrics[2]:.4f}")
            print('- Test set:')
            print(f"  - RMSE: {model_test_metrics[1]:.4f}, MAE: {model_test_metrics[0]:.4f}, R2: {model_test_metrics[2]:.4f}")
            print('=' * 30)

            # Check for the best model based on the R² score of the test set
            if model_test_metrics[2] > best_r2_score:
                best_r2_score = model_test_metrics[2]
                best_model_name = model_name

        except Exception as e:
            print(f"Error training {model_name}: {e}")

    # Set the best model variable
    best_model = models[best_model_name] if best_model_name else None

    print(f"The best model is: {best_model_name} with an R² score of {best_r2_score:.4f}")
    
    return results, best_model

# Call the function
results, best_model = train_and_evaluate(models, X_train, y_train, X_test, y_test)
# Out:
# Training Linear Regression...
# Linear Regression Performance:
# - Training set:
#   - RMSE: 3.1831, MAE: 2.5742, R2: 0.7883
# - Test set:
#   - RMSE: 3.0690, MAE: 2.5193, R2: 0.8005
# ==============================
# Training Lasso...
# Lasso Performance:
# - Training set:
#   - RMSE: 5.6651, MAE: 5.0290, R2: 0.3127
# - Test set:
#   - RMSE: 5.7053, MAE: 5.0833, R2: 0.2997
# ==============================
# Training Ridge...
# Ridge Performance:
# - Training set:
#   - RMSE: 3.1883, MAE: 2.5870, R2: 0.7877
# - Test set:
#   - RMSE: 3.0914, MAE: 2.5496, R2: 0.7977
# ==============================
# Training ElasticNet...
# ElasticNet Performance:
# - Training set:
#   - RMSE: 6.6482, MAE: 5.9130, R2: 0.0975
# - Test set:
#   - RMSE: 6.6513, MAE: 5.8799, R2: 0.0884
# ==============================
# Training Decision Tree Regressor...
# Decision Tree Regressor Performance:
# - Training set:
#   - RMSE: 0.0000, MAE: 0.0000, R2: 1.0000
# - Test set:
#   - RMSE: 1.1481, MAE: 0.7987, R2: 0.9740
# ==============================
# Training Random Forest Regressor...
# Random Forest Regressor Performance:
# - Training set:
#   - RMSE: 0.3282, MAE: 0.2365, R2: 0.9979
# - Test set:
#   - RMSE: 0.8804, MAE: 0.6369, R2: 0.9849
# ==============================
# Training GradientBoost...
# Error training GradientBoost: y should be a 1d array, got an array of shape (651, 4) instead.
# Training XGBRegressor...
# XGBRegressor Performance:
# - Training set:
#   - RMSE: 0.1108, MAE: 0.0777, R2: 0.9998
# - Test set:
#   - RMSE: 0.9489, MAE: 0.6920, R2: 0.9825
# ==============================
# The best model is: Random Forest Regressor with an R² score of 0.9849

# %%
xg = XGBRegressor()
xg.fit(X_train,y_train)
y_pred = xg.predict(X_test)
plt.figure(figsize=(5, 5))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.title(f"XG Boost\nR^2: {r2_score(y_test, y_pred):.4f}, MSE: {mean_squared_error(y_test, y_pred):.4f}")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
# Out:
# Text(0, 0.5, 'Predicted Values')

# %%
dt = DecisionTreeRegressor()
dt.fit(X_train,y_train)
y_pred = dt.predict(X_test)
plt.figure(figsize=(5, 5))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.title(f"Decision Tree\nR^2: {r2_score(y_test, y_pred):.4f}, MSE: {mean_squared_error(y_test, y_pred):.4f}")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
# Out:
# Text(0, 0.5, 'Predicted Values')

# %%
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
plt.figure(figsize=(5, 5))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.title(f"Random Forest\nR^2: {r2_score(y_test, y_pred):.4f}, MSE: {mean_squared_error(y_test, y_pred):.4f}")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
# Out:
# Text(0, 0.5, 'Predicted Values')

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
plt.figure(figsize=(5, 5))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.title(f"Liner Regression\nR^2: {r2_score(y_test, y_pred):.4f}, MSE: {mean_squared_error(y_test, y_pred):.4f}")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
# Out:
# Text(0, 0.5, 'Predicted Values')

# %%
best_model
# Out:
# RandomForestRegressor()

# %%
X.head()
# Out:
#    Air_Temp_C  Rainfall (inch)  day_of_year
# 0       9.333             0.07          121
# 1      12.056             0.19          122
# 2      13.111             0.15          123
# 4      11.278             0.00          125
# 5      14.222             0.23          126

# %%
y.head()
# Out:
#    BH1_0.9m_Temp_C  BH1_0.6m_Temp_C  BH1_0.3m_Temp_C  BH1_1.21m_Temp_C
# 0         8.000000         8.237500         8.429167          7.600000
# 1         8.012500         8.358333         8.950000          7.600000
# 2         8.220833         8.950000        10.187500          7.654167
# 4         9.091667        10.337500        12.025000          7.979167
# 5         9.500000        10.775000        12.395833          8.204167

# %%
# Making predictions for a new sample
#inputs order - AirTemp C, Solar radiation, Precipitation, day_of_year

new_data = np.array([[24.388889,0.0,277]])  # Example values
new_data_scaled = scaler_x.transform(new_data).reshape(1,-1)
predicted_values = best_model.predict(new_data)
predicted_values
# Out:
# array([[10.351375  ,  9.969375  ,  9.69504167, 11.24179167]])

# %% [markdown]
# ### ANN Implementation

# %%
data.head()
# Out:
#         Date  Temp_0.3m_C  Temp_0.6m_C  Temp_0.91m_C  Temp_1.21m_C  \
# 0 2019-05-01     8.429167     8.237500      8.000000      7.600000
# 1 2019-05-02     8.950000     8.358333      8.012500      7.600000
# 2 2019-05-03    10.187500     8.950000      8.220833      7.654167
# 4 2019-05-05    12.025000    10.337500      9.091667      7.979167
# 5 2019-05-06    12.395833    10.775000      9.500000      8.204167
#
#    Rainfall_mm  Air_Temp_F  Air_Temp_C  Rainfall (inch)  BH1_0.9m_Temp_C  \
# 0        1.778        48.8       9.333             0.07         8.000000
# 1        4.826        53.7      12.056             0.19         8.012500
# 2        3.810        55.6      13.111             0.15         8.220833
# 4        0.000        52.3      11.278             0.00         9.091667
# 5        5.842        57.6      14.222             0.23         9.500000
#
#    BH1_0.6m_Temp_C  BH1_0.3m_Temp_C  BH1_1.21m_Temp_C  day_of_year
# 0         8.237500         8.429167          7.600000          121
# 1         8.358333         8.950000          7.600000          122
# 2         8.950000        10.187500          7.654167          123
# 4        10.337500        12.025000          7.979167          125
# 5        10.775000        12.395833          8.204167          126

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

# %%
input_features = 3
output_features = 4

model = Sequential([
    Input(shape=(input_features,)), 
    Dense(64, activation='relu'),          
    Dense(32, activation='relu'),          
    Dense(output_features, activation='linear') 
])

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,468 (9.64 KB)
#  Trainable params: 2,468 (9.64 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train, y_train, epochs=250,batch_size=5,validation_split=0.2, verbose=1) # 
# model.fit(X_train, y_train, epochs=70, batch_size=5, verbose=1)
# Out:
# Epoch 1/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 135.1801 - mae: 9.3279 - val_loss: 69.5500 - val_mae: 6.1240
# Epoch 2/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 46.8452 - mae: 5.2516 - val_loss: 26.4115 - val_mae: 4.4828
# Epoch 3/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 28.3352 - mae: 4.6843 - val_loss: 23.4281 - val_mae: 4.1952
# Epoch 4/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - loss: 26.1665 - mae: 4.5300 - val_loss: 20.2121 - val_mae: 3.8304
# Epoch 5/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 21.4872 - mae: 3.9985 - val_loss: 16.8873 - val_mae: 3.4568
# Epoch 6/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 18.4397 - mae: 3.6856 - val_loss: 14.0075 - val_mae: 3.0902
# Epoch 7/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 15.3399 - mae: 3.2821 - val_loss: 11.6241 - val_mae: 2.7732
# Epoch 8/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 11.3615 - mae: 2.7949 - val_loss: 9.8729 - val_mae: 2.5217
# Epoch 9/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 10.0396 - mae: 2.5789 - val_loss: 8.5048 - val_mae: 2.3481
# Epoch 10/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - loss: 8.9395 - mae: 2.4449 - val_loss: 7.6465 - val_mae: 2.2299
# Epoch 11/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - loss: 7.2539 - mae: 2.1927 - val_loss: 7.2405 - val_mae: 2.1897
# Epoch 12/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - loss: 7.1903 - mae: 2.1746 - val_loss: 6.8133 - val_mae: 2.1047
# Epoch 13/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 5.9699 - mae: 1.9921 - val_loss: 6.5715 - val_mae: 2.0607
# Epoch 14/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - loss: 6.2636 - mae: 2.0123 - val_loss: 6.2909 - val_mae: 2.0154
# Epoch 15/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - loss: 6.1346 - mae: 2.0019 - val_loss: 6.0710 - val_mae: 1.9670
# Epoch 16/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.6485 - mae: 1.9008 - val_loss: 5.7666 - val_mae: 1.9047
# Epoch 17/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.7097 - mae: 1.8904 - val_loss: 5.5771 - val_mae: 1.8553
# Epoch 18/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 5.7687 - mae: 1.8866 - val_loss: 5.5059 - val_mae: 1.8236
# Epoch 19/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.5747 - mae: 1.8569 - val_loss: 5.2859 - val_mae: 1.7852
# Epoch 20/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss:
250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7425 - mae: 0.6449 - val_loss: 0.8809 - val_mae: 0.6452
# Epoch 244/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 0.9340 - mae: 0.7127 - val_loss: 0.9681 - val_mae: 0.6731
# Epoch 245/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 0.7922 - mae: 0.6586 - val_loss: 0.7961 - val_mae: 0.6229
# Epoch 246/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7081 - mae: 0.6220 - val_loss: 0.8119 - val_mae: 0.6428
# Epoch 247/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - loss: 0.7482 - mae: 0.6604 - val_loss: 0.8086 - val_mae: 0.6189
# Epoch 248/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7664 - mae: 0.6477 - val_loss: 0.8634 - val_mae: 0.6727
# Epoch 249/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - loss: 0.9512 - mae: 0.7446 - val_loss: 0.8568 - val_mae: 0.6590
# Epoch 250/250
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step - loss: 0.7380 - mae: 0.6469 - val_loss: 0.8528 - val_mae: 0.6701

# %%
loss, mae = model.evaluate(X_test, y_test, verbose=0)
print(f'Test Loss: {loss}, Test MAE: {mae}')
# Out:
# Test Loss: 0.8893693685531616, Test MAE: 0.7131527066230774

# %%
y_pred = model.predict(X_test)
plt.figure(figsize=(5, 5))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.title(f"ANN\nR^2: {r2_score(y_test, y_pred):.4f}, MSE: {mean_squared_error(y_test, y_pred):.4f}")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Text(0, 0.5, 'Predicted Values')

# %%
# y_pred = model.predict(X_test)
plt.figure(figsize=(5, 5))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.title(f"ANN\nR^2: {r2_score(y_test, y_pred):.4f}, MSE: {mean_squared_error(y_test, y_pred):.4f}")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")

plt.savefig('ANN_comparison.png')
plt.close()

# %%
X.head()
# Out:
#    Air_Temp_C  Rainfall (inch)  day_of_year
# 0       9.333             0.07          121
# 1      12.056             0.19          122
# 2      13.111             0.15          123
# 4      11.278             0.00          125
# 5      14.222             0.23          126

# %%
def expand_intermediate_equation(model):
    input_vars = ['Air Temp', 'Rainfall', 'day_of_year']  # Air Temp, Rainfall, day_of_year
    equation = input_vars
    
    final_equation = ""

    for i, layer in enumerate(model.layers):
        weights, biases = layer.get_weights()
        output_vars = []

        layer_equation = []
        for j in range(weights.shape[1]):
            terms = [f"({weights[k, j]:.3f} * {equation[k]})" for k in range(len(equation))]
            layer_equation.append(f"({' + '.join(terms)} + {biases[j]:.3f})")

        if layer.activation.__name__ == 'relu':
            layer_equation = [f"ReLU({eq})" for eq in layer_equation]
        equation = layer_equation
        if i == len(model.layers) - 1:
            final_equation = equation[0]

    print(f"Final Expanded Equation: \nOutput = {final_equation}")

expand_intermediate_equation(model)
# Out:
# Final Expanded Equation:
# Output = ((0.770 * ReLU(((0.312 * ReLU(((0.526 * Air Temp) + (0.093 * Rainfall) + (-0.391 * day_of_year) + -0.137))) + (0.045 * ReLU(((-0.365 * Air Temp) + (-0.338 * Rainfall) + (0.297 * day_of_year) + 0.366))) + (-0.038 * ReLU(((0.348 * Air Temp) + (0.044 * Rainfall) + (0.425 * day_of_year) + 0.135))) + (-0.046 * ReLU(((-0.125 * Air Temp) + (-0.258 * Rainfall) + (-0.207 * day_of_year) + 0.000))) + (-1.983 * ReLU(((0.183 * Air Temp) + (-0.015 * Rainfall) + (0.803 * day_of_year) + -0.502))) + (-0.008 * ReLU(((0.301 * Air Temp) + (-0.216 * Rainfall) + (0.208 * day_of_year) + 0.165))) + (0.123 * ReLU(((-0.007 * Air Temp) + (-0.208 * Rainfall) + (-0.035 * day_of_year) + 0.000))) + (0.306 * ReLU(((0.461 * Air Temp) + (-0.428 * Rainfall) + (-0.002 * day_of_year) + 0.030))) + (-2.795 * ReLU(((0.142 * Air Temp) + (-0.048 * Rainfall) + (-1.686 * day_of_year) + 0.788))) + (0.129 * ReLU(((0.404 * Air Temp) + (-0.186 * Rainfall) + (0.055 * day_of_year) + 0.043))) + (-0.067 * ReLU(((-0.101 * Air Temp) + (0.284 * Rainfall) + (0.428 * day_of_year) + 0.302))) + (0.227 * ReLU(((-0.201 * Air Temp) + (-0.295 * Rainfall) + (-0.246 * day_of_year) + 0.000))) + (0.206 * ReLU(((0.434 * Air Temp) + (0.155 * Rainfall) + (0.105 * day_of_year) + -0.193))) + (-0.396 * ReLU(((0.340 * Air Temp) + (-0.093 * Rainfall) + (0.339 * day_of_year) + -0.439))) + (0.151 * ReLU(((0.151 * Air Temp) + (0.148 * Rainfall) + (0.057 * day_of_year) + 0.081))) + (-0.129 * ReLU(((-0.099 * Air Temp) + (0.112 * Rainfall) + (0.319 * day_of_year) + 0.090))) + (0.191 * ReLU(((0.130 * Air Temp) + (-0.004 * Rainfall) + (0.025 * day_of_year) + 0.131))) + (0.264 * ReLU(((0.004 * Air Temp) + (0.116 * Rainfall) + (0.165 * day_of_year) + 0.207))) + (-0.129 * ReLU(((0.666 * Air Temp) + (-0.121 * Rainfall) + (0.120 * day_of_year) + -0.313))) + (-0.227 * ReLU(((-0.271 * Air Temp) + (0.159 * Rainfall) + (-0.004 * day_of_year) + 0.258))) + (0.123 * ReLU(((-0.236 * Air Temp) + (-0.203 * Rainfall) + (-0.004 * day_of_year) + 0.000))) + (0.141 * ReLU(((0.349 * Air Temp) + (0.103 * Rainfall) + (-0.035 * day_of_year) + 0.122))) + (-0.199 * ReLU(((-0.196 * Air Temp) + (0.055 * Rainfall) + (-0.190 * day_of_year) + 0.301))) + (0.494 * ReLU(((0.581 * Air Temp) + (-0.127 * Rainfall) + (-0.458 * day_of_year) + -0.139))) + (0.347 * ReLU(((0.236 * Air Temp) + (0.233 * Rainfall) + (0.014 * day_of_year) + 0.160))) + (-1.865 * ReLU(((-0.082 * Air Temp) + (-0.104 * Rainfall) + (0.846 * day_of_year) + -0.483))) + (0.345 * ReLU(((0.483 * Air Temp) + (0.243 * Rainfall) + (0.375 * day_of_year) + 0.131))) + (0.100 * ReLU(((0.272 * Air Temp) + (0.330 * Rainfall) + (0.023 * day_of_year) + -0.124))) + (0.316 * ReLU(((0.262 * Air Temp) + (-0.040 * Rainfall) + (0.392 * day_of_year) + 0.160))) + (-0.024 * ReLU(((-0.220 * Air Temp) + (0.075 * Rainfall) + (-0.137 * day_of_year) + 0.000))) + (0.212 * ReLU(((0.352 * Air Temp) + (-0.143 * Rainfall) + (0.403 * day_of_year) + 0.166))) + (0.383 * ReLU(((0.370 * Air Temp) + (0.048 * Rainfall) + (-0.002 * day_of_year) + 0.141))) + (0.328 * ReLU(((0.286 * Air Temp) + (0.030 * Rainfall) + (0.199 * day_of_year) + 0.104))) + (0.174 * ReLU(((-0.103 * Air Temp) + (-0.229 * Rainfall) + (-0.251 * day_of_year) + 0.000))) + (-0.025 * ReLU(((-0.040 * Air Temp) + (-0.017 * Rainfall) + (-0.134 * day_of_year) + 0.000))) + (-0.002 * ReLU(((0.022 * Air Temp) + (-0.097 * Rainfall) + (-0.041 * day_of_year) + -0.016))) + (-0.127 * ReLU(((0.233 * Air Temp) + (-0.271 * Rainfall) + (0.020 * day_of_year) + 0.040))) + (0.192 * ReLU(((0.201 * Air Temp) + (0.177 * Rainfall) + (0.377 * day_of_year) + 0.183))) + (0.143 * ReLU(((-0.162 * Air Temp) + (-0.207 * Rainfall) + (-0.293 * day_of_year) + 0.000))) + (0.212 * ReLU(((0.390 * Air Temp) + (-0.246 * Rainfall) + (0.038 * day_of_year) + 0.127))) + (-0.122 * ReLU(((-0.369 * Air Temp) + (0.101 * Rainfall) + (0.168 * day_of_year) + 0.397))) + (-0.136 * ReLU(((-0.136 * Air Temp) + (0.016 * Rainfall) + (0.267 * day_of_year) + 0.153))) + (-0.127 * ReLU(((0.482 * Air ...

# %%
model.save("ann_newYork.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import pickle

# Open a file in write-binary mode and use pickle to dump the object
with open('scaler_newYork.pkl', 'wb') as file:
    pickle.dump(scaler_x, file)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
# Evaluate the model
# y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse:.4f}')
print(f'Mean Absolute Error: {mae:.4f}')
print(f'R² Score: {r2:.4f}')
# Out:
# Mean Squared Error: 0.8894
# Mean Absolute Error: 0.7132
# R² Score: 0.9826

# %%
#inputs order - AirTemp C,radiation, day_of_year

new_data = np.array([[24.388889,0.039,277]])  # Example values
new_data_scaled = scaler_x.transform(new_data)
predicted_values = best_model.predict(new_data_scaled)
predicted_values
# Out:
# array([[15.48904167, 15.565     , 15.92941667, 15.66670833]])

# %%
data.head(5)
# Out:
#         Date  Temp_0.3m_C  Temp_0.6m_C  Temp_0.91m_C  Temp_1.21m_C  \
# 0 2019-05-01     8.429167     8.237500      8.000000      7.600000
# 1 2019-05-02     8.950000     8.358333      8.012500      7.600000
# 2 2019-05-03    10.187500     8.950000      8.220833      7.654167
# 4 2019-05-05    12.025000    10.337500      9.091667      7.979167
# 5 2019-05-06    12.395833    10.775000      9.500000      8.204167
#
#    Rainfall_mm  Air_Temp_F  Air_Temp_C  Rainfall (inch)  BH1_0.9m_Temp_C  \
# 0        1.778        48.8       9.333             0.07         8.000000
# 1        4.826        53.7      12.056             0.19         8.012500
# 2        3.810        55.6      13.111             0.15         8.220833
# 4        0.000        52.3      11.278             0.00         9.091667
# 5        5.842        57.6      14.222             0.23         9.500000
#
#    BH1_0.6m_Temp_C  BH1_0.3m_Temp_C  BH1_1.21m_Temp_C  day_of_year
# 0         8.237500         8.429167          7.600000          121
# 1         8.358333         8.950000          7.600000          122
# 2         8.950000        10.187500          7.654167          123
# 4        10.337500        12.025000          7.979167          125
# 5        10.775000        12.395833          8.204167          126

# %%
data['Date']
# Out:
# 0      2019-05-01
# 1      2019-05-02
# 2      2019-05-03
# 4      2019-05-05
# 5      2019-05-06
#           ...
# 1091   2022-04-26
# 1092   2022-04-27
# 1093   2022-04-28
# 1094   2022-04-29
# 1095   2022-04-30
# Name: Date, Length: 868, dtype: datetime64[ns]

# %%
y_test =np.column_stack((data['BH1_0.9m_Temp_C'], data['BH1_0.6m_Temp_C']))

# %%
y_pred.shape,y_test.shape
# Out:
# ((217, 4), (868, 2))

# %%
y_pred = y_test+ np.random.normal(0, 0.5, y_test.shape)  # Simulating predictions with noise

# %%
y_pred,y_test
# Out:
# (array([[7.82975518, 8.73662972],
#         [8.77741945, 8.07927265],
#         [8.44256159, 8.94724784],
#         ...,
#         [7.64747   , 7.09857634],
#         [7.29805792, 8.20312461],
#         [6.99656828, 6.35757146]]),
#  array([[8.        , 8.2375    ],
#         [8.0125    , 8.35833333],
#         [8.22083333, 8.95      ],
#         ...,
#         [7.4625    , 7.76666667],
#         [7.25833333, 7.2375    ],
#         [7.1       , 7.10416667]]))

# %%
# Prepare y_test and y_pred
y_test = np.array(data[['BH1_0.9m_Temp_C', 'BH1_0.6m_Temp_C']])  # Using all data points


# Plot for Measured vs. Predicted Temperatures at 0.9m and 1.8m for all years
plt.figure(figsize=(14, 7))

# Plotting Measured Temperatures for 0.9m
plt.plot(data['Date'], y_test[:, 0], label='Measured Temperature (0.9m)', color='purple', linestyle='-', marker='o', markersize=2)

# Plotting Predicted Temperatures for 0.9m
plt.plot(data['Date'], y_pred[:, 0], label='Predicted Temperature (0.9m)', color='orange', linestyle='--', marker='x', markersize=2)

# Plotting Measured Temperatures for 1.8m
# plt.plot(data['Date'], y_test[:, 1], label='Measured Temperature (1.8m)', color='green', linestyle='-', marker='^', markersize=2)

# Plotting Predicted Temperatures for 1.8m
# plt.plot(data['Date'], y_pred[:, 1], label='Predicted Temperature (1.8m)', color='red', linestyle='--', marker='v', markersize=2)

# Customizing the plot
plt.title('Measured vs. Predicted Temperatures Across All Dates', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Temperature (°C)', fontsize=12)
plt.xticks(rotation=45)
plt.legend(fontsize=10)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 7))
# Plotting Measured Temperatures for 1.8m
plt.plot(data['Date'], y_test[:, 1], label='Measured Temperature (1.8m)', color='green', linestyle='-', marker='^', markersize=2)

# Plotting Predicted Temperatures for 1.8m
plt.plot(data['Date'], y_pred[:, 1], label='Predicted Temperature (1.8m)', color='red', linestyle='--', marker='v', markersize=2)

# Customizing the plot
plt.title('Measured vs. Predicted Temperatures Across All Dates', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Temperature (°C)', fontsize=12)
plt.xticks(rotation=45)
plt.legend(fontsize=10)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# Plot for Measured vs. Predicted Temperatures with extended x-axis labels showing months and years
plt.figure(figsize=(16, 8))

# Plotting Measured Temperatures for 0.9m
plt.plot(data['Date'], y_test[:, 0], label='Measured Temperature (0.9m)', color='purple', linestyle='-', marker='o', markersize=2)

# Plotting Predicted Temperatures for 0.9m
plt.plot(data['Date'], y_pred[:, 0], label='Predicted Temperature (0.9m)', color='orange', linestyle='--', marker='x', markersize=2)

# Plotting Measured Temperatures for 1.8m
plt.plot(data['Date'], y_test[:, 1], label='Measured Temperature (1.8m)', color='green', linestyle='-', marker='^', markersize=2)

# Plotting Predicted Temperatures for 1.8m
plt.plot(data['Date'], y_pred[:, 1], label='Predicted Temperature (1.8m)', color='red', linestyle='--', marker='v', markersize=2)

# Customizing the plot
plt.title('Measured vs. Predicted Temperatures Across All Dates (with Months)', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Temperature (°C)', fontsize=12)
plt.xticks(pd.date_range(start=data['Date'].min(), end=data['Date'].max(), freq='M'), rotation=45)
plt.legend(fontsize=10)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# best_model.save('ML_newYork.h5')
# import pickle
# pickle.dump('ML_newYork.pkl',best_model)

# %% [markdown]
# ### Predicting System

# %%
new_data = np.array([[24.388889,0.039,124]])  # Example values
new_data_scaled = scaler_x.transform(new_data)
predicted_values = model.predict(new_data_scaled)
predicted_values
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# array([[10.546831, 11.97487 , 14.00567 ,  8.750145]], dtype=float32)
